# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
bankdata=pd.read_csv("D:/analytics/Predictive_Analysis/bank-full.csv")

# %%
bankdata.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
bankdata.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
pd.value_counts(bankdata['y'])
# Out:
# no     39922
# yes     5289
# Name: y, dtype: int64

# %%
pd.value_counts(bankdata['y']).plot(kind="bar")

# %%
pd.value_counts(bankdata['marital']).plot(kind="bar")

# %%
pd.value_counts(bankdata['job']).plot(kind="bar")

# %%
pd.value_counts(bankdata['education']).plot(kind="bar")

# %%
pd.value_counts(bankdata['default']).plot(kind="bar")

# %%
pd.value_counts(bankdata['housing']).plot(kind="bar")

# %%
pd.value_counts(bankdata['loan']).plot(kind="bar")

# %%
pd.value_counts(bankdata['contact']).plot(kind="bar")

# %%
pd.value_counts(bankdata['month']).plot(kind="bar")

# %%
pd.value_counts(bankdata['poutcome']).plot(kind="bar")

# %%
pd.value_counts(bankdata['loan']).plot(kind="bar")

# %%
pd.value_counts(bankdata['y']).plot(kind="pie")

# %%
pd.crosstab(bankdata.y,bankdata.job)
# Out:
# job  admin.  blue-collar  entrepreneur  housemaid  management  retired  \
# y
# no     4540         9024          1364       1131        8157     1748
# yes     631          708           123        109        1301      516
#
# job  self-employed  services  student  technician  unemployed  unknown
# y
# no            1392      3785      669        6757        1101      254
# yes            187       369      269         840         202       34

# %%
pd.crosstab(bankdata.job,bankdata.y).plot(kind="bar",stacked=True)

# %%
pd.crosstab(bankdata.marital,bankdata.y).plot(kind="bar",stacked=True)

# %%
pd.crosstab(bankdata.loan,bankdata.y).plot(kind="bar",stacked=True)

# %%
pd.crosstab(bankdata.poutcome,bankdata.y).plot(kind="bar",stacked=True)

# %%
pd.crosstab(bankdata.month,bankdata.y).plot(kind="bar",stacked=True)

# %%
pd.crosstab(bankdata.contact,bankdata.y).plot(kind="bar",stacked=True)

# %%
pd.crosstab(bankdata.housing,bankdata.y).plot(kind="bar",stacked=True)

# %%
pd.crosstab(bankdata.housing,bankdata.y).plot(kind="bar",stacked=True)

# %%
pd.crosstab(bankdata.default,bankdata.y).plot(kind="bar",stacked=True)

# %%
pd.crosstab(bankdata.education,bankdata.y).plot(kind="bar",stacked=True)

# %%
bankdata["age"].groupby(bankdata["job"]).mean()
# Out:
# job
# admin.           39.289886
# blue-collar      40.044081
# entrepreneur     42.190989
# housemaid        46.415323
# management       40.449567
# retired          61.626767
# self-employed    40.484484
# services         38.740250
# student          26.542644
# technician       39.314598
# unemployed       40.961627
# unknown          47.593750
# Name: age, dtype: float64

# %%
bankdata["age"].groupby(bankdata["job"]).median()
# Out:
# job
# admin.           38
# blue-collar      39
# entrepreneur     41
# housemaid        47
# management       38
# retired          59
# self-employed    39
# services         37
# student          26
# technician       37
# unemployed       40
# unknown          47
# Name: age, dtype: int64

# %%
bankdata["age"].groupby(bankdata["marital"]).mean()
# Out:
# marital
# divorced    45.782984
# married     43.408099
# single      33.703440
# Name: age, dtype: float64

# %%
bankdata["age"].groupby(bankdata["marital"]).median()
# Out:
# marital
# divorced    45
# married     42
# single      32
# Name: age, dtype: int64

# %%
bankdata["age"].groupby(bankdata["default"]).mean()
# Out:
# default
# no     40.961934
# yes    39.534969
# Name: age, dtype: float64

# %%
bankdata["age"].groupby(bankdata["default"]).median()
# Out:
# default
# no     39
# yes    38
# Name: age, dtype: int64

# %%
bankdata["age"].groupby(bankdata["housing"]).mean()
# Out:
# housing
# no     43.139883
# yes    39.175288
# Name: age, dtype: float64

# %%
bankdata["age"].groupby(bankdata["housing"]).median()
# Out:
# housing
# no     42
# yes    38
# Name: age, dtype: int64

# %%
bankdata["balance"].groupby(bankdata["job"]).mean()
# Out:
# job
# admin.           1135.838909
# blue-collar      1078.826654
# entrepreneur     1521.470074
# housemaid        1392.395161
# management       1763.616832
# retired          1984.215106
# self-employed    1647.970868
# services          997.088108
# student          1388.060768
# technician       1252.632092
# unemployed       1521.745971
# unknown          1772.357639
# Name: balance, dtype: float64

# %%
bankdata["balance"].groupby(bankdata["job"]).median()
# Out:
# job
# admin.           396.0
# blue-collar      388.0
# entrepreneur     352.0
# housemaid        406.0
# management       572.0
# retired          787.0
# self-employed    526.0
# services         339.5
# student          502.0
# technician       421.0
# unemployed       529.0
# unknown          677.0
# Name: balance, dtype: float64
