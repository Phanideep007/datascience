# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt          
# %matplotlib inline

# %%
mobiledata_train=pd.read_csv("D:/analytics/Hackathon/Mckensy_/train.csv")

# %%
mobiledata_train.head()
# Out:
#   user_sequence  user_id  challenge_sequence challenge
# 0        4576_1     4576                   1   CI23714
# 1        4576_2     4576                   2   CI23855
# 2        4576_3     4576                   3   CI24917
# 3        4576_4     4576                   4   CI23663
# 4        4576_5     4576                   5   CI23933

# %%
mobiledata_train.dtypes
# Out:
# user_sequence         object
# user_id                int64
# challenge_sequence     int64
# challenge             object
# dtype: object

# %%
(mobiledata_train.isnull().sum()).sort_values(ascending=False)  ## to find out number of missing values(NA) columns
# Out:
# challenge             0
# challenge_sequence    0
# user_id               0
# user_sequence         0
# dtype: int64

# %%
#mobiledata_train["publish_date "] = pd.to_datetime(mobiledata_train["publish_date"] ) #to convert into date data type

# %%
#mobiledata_train['year']=pd.DatetimeIndex(mobiledata_train['publish_date']).year
#mobiledata_train['month']=pd.DatetimeIndex(mobiledata_train['publish_date']).month
#mobiledata_train['days']=pd.DatetimeIndex(mobiledata_train['publish_date']).day

#split the year/month/week

# %%
#mobiledata_train1 = mobiledata_train.rename(columns={'challenge': 'challenge_ID'})

# %%
#mobiledata_train1.head()
# Out:
#   user_sequence  user_id  challenge_sequence challenge_ID
# 0        4576_1     4576                   1      CI23714
# 1        4576_2     4576                   2      CI23855
# 2        4576_3     4576                   3      CI24917
# 3        4576_4     4576                   4      CI23663
# 4        4576_5     4576                   5      CI23933

# %%
mobiledata_challenge=pd.read_csv("D:/analytics/Hackathon/Mckensy_/challenge_data.csv")

# %%
mobiledata_challenge.head()
# Out:
#   challenge_ID  programming_language challenge_series_ID  total_submissions  \
# 0      CI23478                     2              SI2445               37.0
# 1      CI23479                     2              SI2435               48.0
# 2      CI23480                     1              SI2435               15.0
# 3      CI23481                     1              SI2710              236.0
# 4      CI23482                     2              SI2440              137.0
#
#   publish_date author_ID author_gender author_org_ID  category_id
# 0   06-05-2006  AI563576             M     AOI100001          NaN
# 1   17-10-2002  AI563577             M     AOI100002         32.0
# 2   16-10-2002  AI563578             M     AOI100003          NaN
# 3   19-09-2003  AI563579             M     AOI100004         70.0
# 4   21-03-2002  AI563580             M     AOI100005          NaN

# %%
mobiledata_challenge.dtypes
# Out:
# challenge_ID             object
# programming_language      int64
# challenge_series_ID      object
# total_submissions       float64
# publish_date             object
# author_ID                object
# author_gender            object
# author_org_ID            object
# category_id             float64
# dtype: object

# %%
(mobiledata_challenge.isnull().sum()).sort_values(ascending=False)  ## to find out number of missing values(NA) columns
# Out:
# category_id             1841
# total_submissions        352
# author_org_ID            248
# author_gender             97
# author_ID                 39
# challenge_series_ID       12
# publish_date               0
# programming_language       0
# challenge_ID               0
# dtype: int64

# %%
mobiledata_challenge['category_id'].describe()
# Out:
# count    3765.000000
# mean       81.083665
# std        56.367797
# min        22.000000
# 25%        36.000000
# 50%        66.000000
# 75%       113.000000
# max       304.000000
# Name: category_id, dtype: float64

# %%
mobiledata_challenge['category_id']=mobiledata_challenge['category_id'].fillna(113) #fill NA values for category_id

# %%
(mobiledata_challenge.isnull().sum()).sort_values(ascending=False)  ## to find out number of missing values(NA) columns
# Out:
# total_submissions       352
# author_org_ID           248
# author_gender            97
# author_ID                39
# challenge_series_ID      12
# category_id               0
# publish_date              0
# programming_language      0
# challenge_ID              0
# dtype: int64

# %%
mobiledata_challenge['total_submissions'].describe()
# Out:
# count     5254.000000
# mean       348.362581
# std       1044.810816
# min          2.000000
# 25%         67.000000
# 50%        134.000000
# 75%        297.000000
# max      43409.000000
# Name: total_submissions, dtype: float64

# %%
mobiledata_challenge['total_submissions']=mobiledata_challenge['total_submissions'].fillna(0) #fill NA values for category_id

# %%
(mobiledata_challenge.isnull().sum()).sort_values(ascending=False)  ## to find out number of missing values(NA) columns
# Out:
# author_org_ID           248
# author_gender            97
# author_ID                39
# challenge_series_ID      12
# category_id               0
# publish_date              0
# total_submissions         0
# programming_language      0
# challenge_ID              0
# dtype: int64

# %%
nonecols=["author_org_ID","author_gender","author_ID","challenge_series_ID"]

# %%
for col in nonecols:
    mobiledata_challenge[col] =  mobiledata_challenge[col].fillna(mobiledata_challenge[col].value_counts().idxmax())

# %%
(mobiledata_challenge.isnull().sum()).sort_values(ascending=False)  ## to find out number of missing values(NA) columns
# Out:
# category_id             0
# author_org_ID           0
# author_gender           0
# author_ID               0
# publish_date            0
# total_submissions       0
# challenge_series_ID     0
# programming_language    0
# challenge_ID            0
# dtype: int64

# %%
mobiledata = pd.merge(mobiledata_train, mobiledata_challenge, how="inner", left_on="challenge", right_on="challenge_ID").drop('challenge',axis=1)

# %%
mobiledata['challenge_ID'].describe()
# Out:
# count      903916
# unique       5348
# top       CI23855
# freq        10016
# Name: challenge_ID, dtype: object

# %%
(mobiledata.isnull().sum()).sort_values(ascending=False)  ## to find out number of missing values(NA) columns
# Out:
# category_id             0
# author_org_ID           0
# author_gender           0
# author_ID               0
# publish_date            0
# total_submissions       0
# challenge_series_ID     0
# programming_language    0
# challenge_ID            0
# challenge_sequence      0
# user_id                 0
# user_sequence           0
# dtype: int64

# %%
mobiledata1=pd.DataFrame(columns=mobiledata.columns) #starting method to import rows from one df to another df

# %%
cond = mobiledata.challenge_sequence > 10
rows = mobiledata.loc[cond, :]

# %%
mobiledata1 = mobiledata1.append(rows, ignore_index=True) #appnding rows copied

# %%
mobiledata1.head()
# Out:
#   user_sequence user_id challenge_sequence challenge_ID programming_language  \
# 0       4662_11    4662                 11      CI23714                    1
# 1       4698_11    4698                 11      CI23714                    1
# 2       4728_11    4728                 11      CI23714                    1
# 3       4759_11    4759                 11      CI23714                    1
# 4       4777_13    4777                 13      CI23714                    1
#
#   challenge_series_ID  total_submissions publish_date author_ID author_gender  \
# 0              SI2477            14723.0   12-06-2006  AI563766             M
# 1              SI2477            14723.0   12-06-2006  AI563766             M
# 2              SI2477            14723.0   12-06-2006  AI563766             M
# 3              SI2477            14723.0   12-06-2006  AI563766             M
# 4              SI2477            14723.0   12-06-2006  AI563766             M
#
#   author_org_ID  category_id
# ...

# %%
mobiledata.drop(rows.index, inplace=True) # dropping rows which are copiped

# %%
mobiledata1.head(50)
# Out:
#    user_sequence user_id challenge_sequence challenge_ID programming_language  \
# 0        4662_11    4662                 11      CI23714                    1
# 1        4698_11    4698                 11      CI23714                    1
# 2        4728_11    4728                 11      CI23714                    1
# 3        4759_11    4759                 11      CI23714                    1
# 4        4777_13    4777                 13      CI23714                    1
# 5        4849_12    4849                 12      CI23714                    1
# 6        4882_11    4882                 11      CI23714                    1
# 7        4917_13    4917                 13      CI23714                    1
# 8        4932_13    4932                 13      CI23714                    1
# 9        4937_11    4937                 11      CI23714                    1
# 10       4965_13    4965                 13      CI23714                    1
# ...

# %%
#from sklearn import preprocessing     #for normalzing data

# %%
#mobiledatadf1=pd.DataFrame(preprocessing.scale(mobiledata_trainvalues1),columns = mobiledata_trainvalues1.columns)  #normalize data

# %%
#mobiledatadf1.head()
# Out:
#    user_sequence   user_id  challenge_sequence  challenge_id  \
# 0      -0.157579 -1.732026           -1.566699     -1.335772
# 1      -0.157569 -1.732026           -1.218544     -1.230228
# 2      -0.157564 -1.732026           -0.870388     -0.443446
# 3      -0.157559 -1.732026           -0.522233     -1.375750
# 4      -0.157554 -1.732026           -0.174078     -1.171059
#
#    programming_language  challenge_series_id  total_submissions  publish_date  \
# 0             -0.077559            -1.108029           1.176115     -0.220824
# 1             -0.077559            -1.205235           1.185024      1.090733
# 2             -0.077559            -0.373580           1.187994     -1.470851
# 3             -0.077559            -1.162032           1.158295      0.145117
# 4             -0.077559            -1.205235           1.179085      1.411336
#
#    author_id  author_gender  author_org_id  category_id
# 0  -1.075365       0.322797      -0.568613    -1.016459
# ...

# %%
mobiledata_test=pd.read_csv("D:/analytics/Hackathon/Mckensy_/sample.csv")

# %%
mobiledata_test.head()
# Out:
#   user_sequence challenge
# 0       4577_11   CI23648
# 1       4577_12   CI23648
# 2       4577_13   CI23648
# 3       4578_11   CI23648
# 4       4578_12   CI23648

# %%
mobiledata_test = pd.merge([mobiledata_test, mobiledata_challenge])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-217c30d659a0> in <module>()
# ----> 1 mobiledata_test = pd.merge([mobiledata_test, mobiledata_challenge])
#
# TypeError: merge() missing 1 required positional argument: 'right'

# %%
mobiledata_test.head(50)
# Out:
#    author_ID author_gender author_org_ID  category_id challenge challenge_ID  \
# 0        NaN           NaN           NaN          NaN   CI23648          NaN
# 1        NaN           NaN           NaN          NaN   CI23648          NaN
# 2        NaN           NaN           NaN          NaN   CI23648          NaN
# 3        NaN           NaN           NaN          NaN   CI23648          NaN
# 4        NaN           NaN           NaN          NaN   CI23648          NaN
# 5        NaN           NaN           NaN          NaN   CI23648          NaN
# 6        NaN           NaN           NaN          NaN   CI23648          NaN
# 7        NaN           NaN           NaN          NaN   CI23648          NaN
# 8        NaN           NaN           NaN          NaN   CI23648          NaN
# 9        NaN           NaN           NaN          NaN   CI23648          NaN
# 10       NaN           NaN           NaN          NaN   CI23648          NaN
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
mobiledata=mobiledata.apply(le.fit_transform)

# %%
mobiledata.head().transpose()
# Out:
#                            0       1       2       3       4
# user_sequence         316030  316276  316388  316586  316946
# user_id                    0       1       3       4       6
# challenge_sequence         0       5       7       5       5
# challenge_ID             212     212     212     212     212
# programming_language       0       0       0       0       0
# challenge_series_ID       40      40      40      40      40
# total_submissions       1061    1061    1061    1061    1061
# publish_date             445     445     445     445     445
# author_ID                171     171     171     171     171
# author_gender              1       1       1       1       1
# author_org_ID            119     119     119     119     119
# category_id                7       7       7       7       7

# %%
y=mobiledata.challenge_ID
X=mobiledata.drop(["user_id","challenge_ID"],axis=1)

# %%
from sklearn.ensemble import RandomForestRegressor         ## Random Forest ##

# %%
rf =  RandomForestRegressor(n_estimators=100)

# %%
rf.fit(X,y)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
rf.score(X,y)
# Out:
# 0.99999322437516103

# %%
predict = rf.predict(X)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
mobiledata_test=mobiledata_test.apply(le.fit_transform)

# %%
mobiledata_test.head().transpose()
# Out:
#                            0       1       2       3       4
# user_sequence         180100  180162  180432  180480  180552
# user_id                    0       1       3       4       5
# challenge_sequence         0       1       1       0       1
# challenge_ID             326     326     326     326     326
# programming_language       0       0       0       0       0
# challenge_series_ID       32      32      32      32      32
# total_submissions       1059    1059    1059    1059    1059
# publish_date             819     819     819     819     819
# author_ID                218     218     218     218     218
# author_gender              1       1       1       1       1
# author_org_ID            187     187     187     187     187
# category_id                6       6       6       6       6

# %%
X1=mobiledata_test.drop(["user_id","challenge_ID","user_sequence","challenge_sequence"],axis=1)

# %%
predict1=rf.predict(X1)

# %%
pd.DataFrame(predict1).to_csv("D:/analytics/Hackathon/Mckensy_/rfpredict.csv") #converting to csv download from home of jupyter notebook then convert the values in csv to exp in csv using exp() the file will ne in local folder
